# %% [markdown]
# # Titanic Wrangling
#
# In this practice activity you'll continue to work with the titanic dataset in ways that flex what you've learned about both data wrangling and data visualization.

# %%
# Import the titanic dataset here
import numpy as np
import pandas as pd

data_dir = "https://dlsun.github.io/pods/data/"
df_titanic = pd.read_csv(data_dir + "titanic.csv")
df_titanic

# %% [markdown]
# ## 1. Filter the data to include passengers only. Calculate the joint distribution (cross-tab) between a passenger's class and where they embarked.

# %%
# Code here
df_titanic_passengers=df_titanic[(df_titanic["class"]=="1st")|(df_titanic['class']=='2nd')|(df_titanic['class']=='3rd')]
pd.crosstab(df_titanic_passengers['class'],df_titanic_passengers['embarked'])
# Out:
# embarked  B    C    Q    S
# class
# 1st       3  143    3  175
# 2nd       6   26    7  245
# 3rd       0  102  113  494

# %% [markdown]
# ## 2. Using the joint distribution that calculated above, calculate the following:
#
# * the conditional distribution of their class given where they embarked
# * the conditional distribution of where they embarked given their class
#
# Use the conditional distributions that you calculate to answer the following quesitons:
#
# * What proportion of 3rd class passengers embarked at Southampton?
# * What proportion of Southampton passengers were in 3rd class?

# %%
# Code here
pd.crosstab(df_titanic_passengers['class'],df_titanic_passengers['embarked'],normalize='columns')
# Out:
# embarked         B         C         Q         S
# class
# 1st       0.333333  0.527675  0.024390  0.191466
# 2nd       0.666667  0.095941  0.056911  0.268053
# 3rd       0.000000  0.376384  0.918699  0.540481

# %%
pd.crosstab(df_titanic_passengers['embarked'],df_titanic_passengers['class'],normalize='columns')
# Out:
# class          1st       2nd       3rd
# embarked
# B         0.009259  0.021127  0.000000
# C         0.441358  0.091549  0.143865
# Q         0.009259  0.024648  0.159379
# S         0.540123  0.862676  0.696756

# %% [markdown]
# The proportion of 3rd class passengers that embarked at Southampton is .54.
# The proportion of Southampton passengers that were in 3rd class is .7.

# %% [markdown]
# ## 3. Make a visualization showing the distribution of a passenger's class, given where they embarked.
#
# Discuss the pros and cons of using this visualization versus the distributions you calculated before, to answer the previous questions.

# %%
# Code here
from plotnine import ggplot, aes, geom_bar
ggplot(df_titanic_passengers,aes(x='embarked',fill='class'))+geom_bar(position='fill')
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# The pros of using a bar graph is one can directly see the proportions of 1st, 2nd, and 3rd class passengers given from where they embarked. The downside is that you can't see how many of each type of passenger there are.
